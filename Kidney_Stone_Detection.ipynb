# %%
# Importing Libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation
from keras.preprocessing.image import ImageDataGenerator

# %%
# !python --version
# Out:
# Python 3.8.8

# %%
# Setting the Path
path = 'CT_images'

# %%
# Loading the images
train_data_dir = os.path.join(path, 'Train')
test_data_dir = os.path.join(path, 'Test')

# %%
# Image Preprocessing
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
# Training the Model
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary')

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(150,150),
    batch_size=32,
    class_mode='binary',
    shuffle=False
    )
# Out:
# Found 3000 images belonging to 2 classes.
# Found 900 images belonging to 2 classes.

# %%
model = Sequential()

#Adding convolutional layers
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

#Adding a second convolutional layer
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())  # this converts our feature maps to 1D feature vectors
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
# Compiling the model
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# Training the Model
model.fit(
    train_generator,
    steps_per_epoch=32,
    epochs=46,
    validation_data=test_generator,
    validation_steps=32)
# Out:
# Epoch 1/46
# 32/32 [==============================] - ETA: 0s - loss: 0.3864 - accuracy: 0.8232WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 32 batches). You may need to use the repeat() function when building your dataset.
# 32/32 [==============================] - 80s 2s/step - loss: 0.3864 - accuracy: 0.8232 - val_loss: 0.2471 - val_accuracy: 0.9300
# Epoch 2/46
# 32/32 [==============================] - 41s 1s/step - loss: 0.0611 - accuracy: 0.9823
# Epoch 3/46
# 32/32 [==============================] - 41s 1s/step - loss: 0.0211 - accuracy: 0.9961
# Epoch 4/46
# 32/32 [==============================] - 42s 1s/step - loss: 0.0207 - accuracy: 0.9932
# Epoch 5/46
# 32/32 [==============================] - 42s 1s/step - loss: 0.0054 - accuracy: 0.9980
# Epoch 6/46
# 32/32 [==============================] - 39s 1s/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 7/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 8/46
# 32/32 [==============================] - 39s 1s/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 9/46
# 32/32 [==============================] - 37s 1s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 10/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 11/46
# 32/32 [==============================] - 40s 1s/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 12/46
# 32/32 [==============================] - 37s 1s/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 13/46
# 32/32 [==============================] - 36s 1s/step - loss: 0.0022 - accuracy: 0.9990
# Epoch 14/46
# 32/32 [==============================] - 33s 1s/step - loss: 0.0060 - accuracy: 0.9961
# Epoch 15/46
# 32/32 [==============================] - 36s 1s/step - loss: 0.0064 - accuracy: 0.9980
# Epoch 16/46
# 32/32 [==============================] - 36s 1s/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 17/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 18/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 19/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 20/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0042 - accuracy: 0.9980
# Epoch 21/46
# 32/32 [==============================] - 36s 1s/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 22/46
# 32/32 [==============================] - 36s 1s/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 23/46
# 32/32 [==============================] - 37s 1s/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 24/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 25/46
# 32/32 [==============================] - 36s 1s/step - loss: 9.4889e-04 - accuracy: 1.0000
# Epoch 26/46
# 32/32 [==============================] - 34s 1s/step - loss: 2.5747e-04 - accuracy: 1.0000
# Epoch 27/46
# 32/32 [==============================] - 37s 1s/step - loss: 3.2447e-04 - accuracy: 1.0000
# Epoch 28/46
# 32/32 [==============================] - 35s 1s/step - loss: 1.0549e-04 - accuracy: 1.0000
# Epoch 29/46
# 32/32 [==============================] - 41s 1s/step - loss: 3.3800e-04 - accuracy: 1.0000
# Epoch 30/46
# 32/32 [==============================] - 42s 1s/step - loss: 2.2832e-04 - accuracy: 1.0000
# Epoch 31/46
# 32/32 [==============================] - 36s 1s/step - loss: 1.4701e-04 - accuracy: 1.0000
# Epoch 32/46
# 32/32 [==============================] - 37s 1s/step - loss: 6.0606e-05 - accuracy: 1.0000
# Epoch 33/46
# 32/32 [==============================] - 34s 1s/step - loss: 1.6073e-05 - accuracy: 1.0000
# Epoch 34/46
# 32/32 [==============================] - 34s 1s/step - loss: 2.1448e-05 - accuracy: 1.0000
# Epoch 35/46
# 32/32 [==============================] - 34s 1s/step - loss: 1.1978e-04 - accuracy: 1.0000
# Epoch 36/46
# 32/32 [==============================] - 34s 1s/step - loss: 5.7939e-04 - accuracy: 1.0000
# Epoch 37/46
# 32/32 [==============================] - 34s 1s/step - loss: 3.5608e-05 - accuracy: 1.0000
# Epoch 38/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0013 - accuracy: 0.9990
# Epoch 39/46
# 32/32 [==============================] - 39s 1s/step - loss: 0.0024 - accuracy: 0.9990
# Epoch 40/46
# 32/32 [==============================] - 38s 1s/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 41/46
# 32/32 [==============================] - 38s 1s/step - loss: 0.0019 - accuracy: 0.9990
# Epoch 42/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0073 - accuracy: 0.9980
# Epoch 43/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0023 - accuracy: 0.9990
# Epoch 44/46
# 32/32 [==============================] - 34s 1s/step - loss: 0.0117 - accuracy: 0.9970
# Epoch 45/46
# 32/32 [==============================] - 35s 1s/step - loss: 0.0063 - accuracy: 0.9990
# Epoch 46/46
# 32/32 [==============================] - 35s 1s/step - loss: 9.6829e-04 - accuracy: 1.0000

# %%
# Saving the Model
model.save('kidney_stone_detection_model.h5')

# %%
from keras.models import load_model
model = load_model('kidney_stone_detection_model.h5')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_1 (Activation)   (None, 72, 72, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 64)                2654272
#
#  activation_2 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_3 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 2,664,481
# Trainable params: 2,664,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(test_generator,steps=1)
# Out:
# 1/1 [==============================] - 1s 1s/step - loss: 3.1962e-04 - accuracy: 1.0000
# [0.00031961570493876934, 1.0]
